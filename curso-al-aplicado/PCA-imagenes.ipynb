# %%
# %matplotlib inline
# %pip install imageio

import numpy as np
import imageio
import matplotlib.pyplot as plt
import pandas as pd

# %%
im = imageio.imread('imagenes/gato.jpg')
im = im.astype(np.uint8)

plt.imshow(im)
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_8968\3313129970.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   im = imageio.imread('imagenes/gato.jpg')

# %%
print("Max original", end=" ")
print(im.max())
print("Min original", end=" ")
print(im.min())
# Out:
# Max original 255
# Min original 0

# %%
im_original = im
im = im/255
print("Max original", end=" ")
print(im.max())
print("Min original", end=" ")
print(im.min())
# Out:
# Max original 1.0
# Min original 0.0

# %%
fix, ax = plt.subplots(1, 2, figsize=(12, 12),subplot_kw={'xticks': [], 'yticks': []})
ax[0].imshow(im_original, cmap='gray')
ax[1].imshow(im, cmap='gray')

# %%
from glob import glob

caras = pd.DataFrame([])

for path in iglob()
