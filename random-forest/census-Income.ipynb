# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = './files/Census-Income.csv'
df = pd.read_csv(path, header=None, sep=",")

# %%
df.sample(10)
# Out:
#        0                  1       2              3   4                    5   \
# 16312  17            Private  242773           11th   7        Never-married
# 10433  27            Private  207611        HS-grad   9        Never-married
# 22629  47            Private  251508        HS-grad   9             Divorced
# 11843  26            Private  283715        HS-grad   9        Never-married
# 28909  41            Private  182303   Some-college  10   Married-civ-spouse
# 31619  26   Self-emp-not-inc  231714        HS-grad   9   Married-civ-spouse
# 16242  48   Self-emp-not-inc   97883        HS-grad   9            Separated
# 21728  23            Private   38238      Bachelors  13        Never-married
# 5906   48            Private  186203        HS-grad   9   Married-civ-spouse
# 3246   26            Private  187577      Assoc-voc  11        Never-married
#
#                    6                7       8        9   10  11  12  \
# 16312   Other-service        Own-child   White   Female   0   0  20
# 10433   Other-service    Not-in-family   White   Female   0   0  52
# 22629    Tech-support    Not-in-family   White   Female   0   0  36
# 11843    Craft-repair        Own-child   White     Male   0   0  40
# 28909           Sales          Husband   White     Male   0   0  50
# 31619    Craft-repair          Husband   White     Male   0   0  40
# 16242   Other-service   Other-relative   White   Female   0   0  25
# 21728   Other-service        Own-child   White     Male   0   0  40
# 5906    Other-service          Husband   White     Male   0   0  50
# 3246            Sales    Not-in-family   White     Male   0   0  55
#
#                    13      14
# 16312   United-States   <=50K
# 10433   United-States   <=50K
# 22629   United-States   <=50K
# 11843   United-States   <=50K
# 28909   United-States    >50K
# 31619   United-States   <=50K
# 16242   United-States   <=50K
# 21728   United-States   <=50K
# 5906    United-States   <=50K
# 3246    United-States   <=50K

# %%
columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']
df.columns = columns

# %%
df.sample(10)
# Out:
#        age   workclass  fnlwgt      education  education-num  \
# 30332   39     Private  339442        HS-grad              9
# 28236   18     Private  301814        HS-grad              9
# 23942   43     Private  180096      Assoc-voc             11
# 3990    77           ?  147284        HS-grad              9
# 29205   23     Private  314894        HS-grad              9
# 29036   24     Private  308285        HS-grad              9
# 27249   28     Private   51961   Some-college             10
# 17183   51   Local-gov  156003        HS-grad              9
# 12694   43     Private   33331      Bachelors             13
# 8815    34     Private  106014   Some-college             10
#
#             marital-status          occupation    relationship    race  \
# 30332            Separated   Machine-op-inspct   Not-in-family   Black
# 28236        Never-married               Sales   Not-in-family   White
# 23942   Married-civ-spouse        Craft-repair         Husband   White
# 3990               Widowed                   ?   Not-in-family   White
# 29205        Never-married     Exec-managerial       Own-child   White
# 29036        Never-married        Craft-repair       Own-child   White
# 27249        Never-married        Tech-support       Own-child   Black
# 17183             Divorced     Protective-serv   Not-in-family   White
# 12694   Married-civ-spouse               Sales         Husband   White
# 8815         Never-married       Other-service   Not-in-family   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 30332     Male          2176             0              40   United-States
# 28236   Female             0             0              20   United-States
# 23942     Male             0             0              50   United-States
# 3990    Female             0             0              14   United-States
# 29205   Female             0             0              45   United-States
# 29036     Male             0             0              40   United-States
# 27249     Male             0             0              24   United-States
# 17183     Male             0             0              40   United-States
# 12694     Male             0             0              55   United-States
# 8815      Male             0             0              40   United-States
#
#        income
# 30332   <=50K
# 28236   <=50K
# 23942    >50K
# 3990    <=50K
# 29205   <=50K
# 29036   <=50K
# 27249   <=50K
# 17183   <=50K
# 12694   <=50K
# 8815    <=50K
