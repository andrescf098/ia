# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = './files/Census-Income.csv'
df = pd.read_csv(path, header=None, sep=",")

# %%
df.sample(10)
# Out:
#        0             1       2              3   4                    5   \
# 30454  36       Private  255454        HS-grad   9        Never-married
# 21894  31       Private  144949      Bachelors  13   Married-civ-spouse
# 30601  24   Federal-gov  210736        HS-grad   9        Never-married
# 28201  43       Private  178866        HS-grad   9   Married-civ-spouse
# 29396  22       Private  189277        HS-grad   9        Never-married
# 30698  22             ?  334593   Some-college  10        Never-married
# 24936  30       Private  167309      Bachelors  13   Married-civ-spouse
# 1238   31       Private  185732        HS-grad   9        Never-married
# 20911  47       Private  147236        HS-grad   9   Married-civ-spouse
# 2447   29       Private   32897        HS-grad   9             Divorced
#
#                        6               7       8        9   10    11  12  \
# 30454        Craft-repair       Own-child   Black     Male   0     0  30
# 21894      Prof-specialty         Husband   White     Male   0     0  40
# 30601        Adm-clerical   Not-in-family   White   Female   0  1974  40
# 28201        Adm-clerical            Wife   White   Female   0     0  25
# 29396   Machine-op-inspct       Unmarried   Black   Female   0     0  40
# 30698                   ?   Not-in-family   White     Male   0     0  40
# 24936        Adm-clerical         Husband   White     Male   0  1902  40
# 1238        Other-service       Own-child   White   Female   0     0  30
# 20911        Craft-repair         Husband   White     Male   0     0  40
# 2447        Other-service   Not-in-family   White   Female   0     0  25
#
#                    13      14
# 30454   United-States   <=50K
# 21894   United-States    >50K
# 30601   United-States   <=50K
# 28201   United-States    >50K
# 29396   United-States   <=50K
# 30698   United-States   <=50K
# 24936   United-States    >50K
# 1238    United-States   <=50K
# 20911   United-States    >50K
# 2447    United-States   <=50K

# %%
columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']
df.columns = columns

# %%
df.sample(10)
# Out:
#        age     workclass  fnlwgt      education  education-num  \
# 25453   17       Private  266134           10th              6
# 16942   58       Private  298601            9th              5
# 24141   41     State-gov  222434     Assoc-acdm             12
# 6415    49   Federal-gov  311671   Some-college             10
# 11987   23       Private  107801      Bachelors             13
# 30183   43       Private  328570   Some-college             10
# 8265    24       Private   96178      Bachelors             13
# 15524   43       Private  142444   Some-college             10
# 25056   18             ?   67793        HS-grad              9
# 14888   36       Private  201769           11th              7
#
#             marital-status          occupation    relationship    race  \
# 25453        Never-married       Other-service       Own-child   White
# 16942   Married-civ-spouse   Machine-op-inspct         Husband   Black
# 24141   Married-civ-spouse     Protective-serv         Husband   White
# 6415    Married-civ-spouse     Exec-managerial         Husband   White
# 11987        Never-married        Adm-clerical       Own-child   White
# 30183             Divorced   Machine-op-inspct       Unmarried   Black
# 8265         Never-married        Adm-clerical       Own-child   White
# 15524             Divorced               Sales       Unmarried   White
# 25056        Never-married                   ?       Own-child   White
# 14888        Never-married     Protective-serv   Not-in-family   Black
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 25453     Male             0             0              12   United-States
# 16942     Male          3781             0              40   United-States
# 24141     Male             0             0              40   United-States
# 6415      Male             0             0              40   United-States
# 11987   Female             0             0              20   United-States
# 30183   Female             0             0              38   United-States
# 8265    Female             0             0              40   United-States
# 15524   Female             0             0              55   United-States
# 25056   Female             0             0              60   United-States
# 14888     Male         13550             0              40   United-States
#
#        income
# 25453   <=50K
# 16942   <=50K
# 24141   <=50K
# 6415     >50K
# 11987   <=50K
# 30183   <=50K
# 8265    <=50K
# 15524    >50K
# 25056   <=50K
# 14888    >50K

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64
